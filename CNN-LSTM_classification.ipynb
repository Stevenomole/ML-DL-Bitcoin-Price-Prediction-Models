# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, matthews_corrcoef
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, GlobalAveragePooling1D, AveragePooling1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import Dropout, BatchNormalization
import os
import random
import tensorflow as tf

# %%
# resetting the seeds for reproducibility
def reset_random_seeds():
    n = 1
    os.environ['PYTHONHASHSEED'] = str(n)
    tf.random.set_seed(n)
    np.random.seed(n)
    random.seed(n)

reset_random_seeds()

# import data
df = pd.read_csv('Boruta_onchain_data.csv')
df1 = pd.read_csv('all_data.csv')

#df = df[df['timestamp'] >= '2013-03-11'].reset_index(drop=True)

#onchain_data_new
#TA_data
#all_data
#Boruta_data
#Boruta_onchain_data
#Boruta_TA_data

# %%
# separate the inputs and target
X = df.drop('timestamp', axis=1)

# create binary classification for price movement. this assigns 1 to y if price will move upward next day.
price = pd.DataFrame()
price['today'] = df['price-ohlc-usd-c']
price['next day'] = price['today'].shift(-1)
y = (price['next day'] > price['today']).astype(int)

# separate training data from testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# scale the input data
scaler = StandardScaler()

# Reshape X_train and X_test if they are 1D
if X_train.ndim == 1:
    X_train = X_train.to_numpy().reshape(-1, 1)
if X_test.ndim == 1:
    X_test = X_test.to_numpy().reshape(-1, 1)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# reshape the input data for CNN-LSTM (samples, timesteps, features)
def create_sequences(data, timesteps):
    X = []
    for i in range(len(data) - timesteps + 1):
        X.append(data[i:i + timesteps])
    return np.array(X)

timesteps = 5
X_train_reshaped = create_sequences(X_train_scaled, timesteps)
X_test_reshaped = create_sequences(X_test_scaled, timesteps)
y_train = y_train[timesteps - 1:]
y_test = y_test[timesteps - 1:]

# %%
from tensorflow.keras import backend as K

def f1_score_2(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
# define the CNN-LSTM model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(timesteps, X_train_reshaped.shape[2])))
model.add(BatchNormalization())
model.add(AveragePooling1D(pool_size=1))
model.add(Dropout(0.5))
model.add(LSTM(units=128, return_sequences=True))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(LSTM(units=80))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=[metrics.BinaryAccuracy(), 
                                                                                        metrics.Precision(), metrics.Recall(), f1_score_2])

# %%
# train with the training dataset
early_stopping = EarlyStopping(monitor='val_loss', patience=100)
history = model.fit(X_train_reshaped, y_train, epochs=1000, batch_size=50, validation_split=0.1, callbacks=[early_stopping])
# Out:
# Epoch 1/1000
# 55/55 [==============================] - 6s 27ms/step - loss: 0.9854 - binary_accuracy: 0.4924 - precision: 0.5365 - recall: 0.5230 - f1_score_2: 0.5332 - val_loss: 0.6858 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 2/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.8767 - binary_accuracy: 0.5143 - precision: 0.5542 - recall: 0.5678 - f1_score_2: 0.5644 - val_loss: 0.6870 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 3/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.8539 - binary_accuracy: 0.5046 - precision: 0.5440 - recall: 0.5779 - f1_score_2: 0.5640 - val_loss: 0.6876 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 4/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.8204 - binary_accuracy: 0.5043 - precision: 0.5414 - recall: 0.6070 - f1_score_2: 0.5582 - val_loss: 0.6888 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 5/1000
# 55/55 [==============================] - 1s 10ms/step - loss: 0.7906 - binary_accuracy: 0.5128 - precision: 0.5501 - recall: 0.5955 - f1_score_2: 0.5749 - val_loss: 0.6864 - val_binary_accuracy: 0.5681 - val_precision: 0.5652 - val_recall: 1.0000 - val_f1_score_2: 0.7565
# Epoch 6/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.7635 - binary_accuracy: 0.5068 - precision: 0.5443 - recall: 0.5989 - f1_score_2: 0.5728 - val_loss: 0.7063 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 7/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.7569 - binary_accuracy: 0.5013 - precision: 0.5383 - recall: 0.6145 - f1_score_2: 0.5761 - val_loss: 0.6841 - val_binary_accuracy: 0.5880 - val_precision: 0.6142 - val_recall: 0.7160 - val_f1_score_2: 0.6121
# Epoch 8/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.7449 - binary_accuracy: 0.5035 - precision: 0.5402 - recall: 0.6152 - f1_score_2: 0.5604 - val_loss: 0.6901 - val_binary_accuracy: 0.5748 - val_precision: 0.6376 - val_recall: 0.5621 - val_f1_score_2: 0.3321
# Epoch 9/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.7316 - binary_accuracy: 0.5161 - precision: 0.5509 - recall: 0.6192 - f1_score_2: 0.5686 - val_loss: 0.6941 - val_binary_accuracy: 0.4917 - val_precision: 0.5374 - val_recall: 0.6805 - val_f1_score_2: 0.5853
# Epoch 10/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.7255 - binary_accuracy: 0.5217 - precision: 0.5529 - recall: 0.6518 - f1_score_2: 0.6020 - val_loss: 0.7151 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 11/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.7117 - binary_accuracy: 0.5220 - precision: 0.5519 - recall: 0.6660 - f1_score_2: 0.5892 - val_loss: 0.6889 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 12/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.7128 - binary_accuracy: 0.5250 - precision: 0.5546 - recall: 0.6646 - f1_score_2: 0.6080 - val_loss: 0.6952 - val_binary_accuracy: 0.4784 - val_precision: 0.5333 - val_recall: 0.5680 - val_f1_score_2: 0.5225
# Epoch 13/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6994 - binary_accuracy: 0.5276 - precision: 0.5538 - recall: 0.6972 - f1_score_2: 0.6206 - val_loss: 0.7030 - val_binary_accuracy: 0.4385 - val_precision: 0.5000 - val_recall: 0.0651 - val_f1_score_2: 0.2196
# Epoch 14/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.7031 - binary_accuracy: 0.5265 - precision: 0.5507 - recall: 0.7243 - f1_score_2: 0.6291 - val_loss: 0.7038 - val_binary_accuracy: 0.4419 - val_precision: 0.5031 - val_recall: 0.4852 - val_f1_score_2: 0.4759
# Epoch 15/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.7026 - binary_accuracy: 0.5168 - precision: 0.5434 - recall: 0.7256 - f1_score_2: 0.6089 - val_loss: 0.6972 - val_binary_accuracy: 0.4518 - val_precision: 0.5118 - val_recall: 0.5148 - val_f1_score_2: 0.4955
# Epoch 16/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6966 - binary_accuracy: 0.5291 - precision: 0.5510 - recall: 0.7466 - f1_score_2: 0.6192 - val_loss: 0.6985 - val_binary_accuracy: 0.4352 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 17/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6984 - binary_accuracy: 0.5202 - precision: 0.5442 - recall: 0.7514 - f1_score_2: 0.6157 - val_loss: 0.7074 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 18/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6925 - binary_accuracy: 0.5298 - precision: 0.5519 - recall: 0.7425 - f1_score_2: 0.6372 - val_loss: 0.6990 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 19/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6919 - binary_accuracy: 0.5354 - precision: 0.5522 - recall: 0.7920 - f1_score_2: 0.6539 - val_loss: 0.7176 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 20/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6943 - binary_accuracy: 0.5339 - precision: 0.5501 - recall: 0.8069 - f1_score_2: 0.6574 - val_loss: 0.7130 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 21/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.6922 - binary_accuracy: 0.5342 - precision: 0.5495 - recall: 0.8191 - f1_score_2: 0.6606 - val_loss: 0.7091 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 22/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6920 - binary_accuracy: 0.5368 - precision: 0.5504 - recall: 0.8327 - f1_score_2: 0.6664 - val_loss: 0.7114 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 23/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6901 - binary_accuracy: 0.5424 - precision: 0.5534 - recall: 0.8428 - f1_score_2: 0.6537 - val_loss: 0.6856 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 24/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6916 - binary_accuracy: 0.5383 - precision: 0.5509 - recall: 0.8394 - f1_score_2: 0.6686 - val_loss: 0.6981 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 25/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6902 - binary_accuracy: 0.5302 - precision: 0.5444 - recall: 0.8598 - f1_score_2: 0.6699 - val_loss: 0.7092 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 26/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.6900 - binary_accuracy: 0.5539 - precision: 0.5575 - recall: 0.8896 - f1_score_2: 0.6874 - val_loss: 0.6994 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 27/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.6894 - binary_accuracy: 0.5424 - precision: 0.5514 - recall: 0.8726 - f1_score_2: 0.6784 - val_loss: 0.7134 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 28/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6916 - binary_accuracy: 0.5379 - precision: 0.5479 - recall: 0.8841 - f1_score_2: 0.6792 - val_loss: 0.7016 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 29/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6909 - binary_accuracy: 0.5379 - precision: 0.5463 - recall: 0.9106 - f1_score_2: 0.6862 - val_loss: 0.6991 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 30/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6902 - binary_accuracy: 0.5409 - precision: 0.5497 - recall: 0.8835 - f1_score_2: 0.6627 - val_loss: 0.6964 - val_binary_accuracy: 0.4419 - val_precision: 0.6000 - val_recall: 0.0178 - val_f1_score_2: 0.0252
# Epoch 31/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.6898 - binary_accuracy: 0.5417 - precision: 0.5483 - recall: 0.9153 - f1_score_2: 0.6883 - val_loss: 0.6978 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 32/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6903 - binary_accuracy: 0.5387 - precision: 0.5482 - recall: 0.8855 - f1_score_2: 0.6621 - val_loss: 0.6930 - val_binary_accuracy: 0.5150 - val_precision: 0.6237 - val_recall: 0.3432 - val_f1_score_2: 0.2139
# Epoch 33/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6886 - binary_accuracy: 0.5409 - precision: 0.5488 - recall: 0.8997 - f1_score_2: 0.6843 - val_loss: 0.7077 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 34/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6880 - binary_accuracy: 0.5505 - precision: 0.5552 - recall: 0.8923 - f1_score_2: 0.6866 - val_loss: 0.6849 - val_binary_accuracy: 0.5648 - val_precision: 0.5633 - val_recall: 1.0000 - val_f1_score_2: 0.7553
# Epoch 35/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6878 - binary_accuracy: 0.5479 - precision: 0.5526 - recall: 0.9072 - f1_score_2: 0.6896 - val_loss: 0.7076 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 36/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6915 - binary_accuracy: 0.5402 - precision: 0.5488 - recall: 0.8916 - f1_score_2: 0.6818 - val_loss: 0.6901 - val_binary_accuracy: 0.5781 - val_precision: 0.6071 - val_recall: 0.7041 - val_f1_score_2: 0.5941
# Epoch 37/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6894 - binary_accuracy: 0.5479 - precision: 0.5515 - recall: 0.9248 - f1_score_2: 0.6929 - val_loss: 0.7016 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 38/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6897 - binary_accuracy: 0.5468 - precision: 0.5525 - recall: 0.8977 - f1_score_2: 0.6869 - val_loss: 0.6954 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 39/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6891 - binary_accuracy: 0.5457 - precision: 0.5504 - recall: 0.9207 - f1_score_2: 0.6734 - val_loss: 0.6986 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 40/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6909 - binary_accuracy: 0.5365 - precision: 0.5458 - recall: 0.9045 - f1_score_2: 0.6833 - val_loss: 0.6911 - val_binary_accuracy: 0.5515 - val_precision: 0.6232 - val_recall: 0.5089 - val_f1_score_2: 0.3377
# Epoch 41/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6904 - binary_accuracy: 0.5402 - precision: 0.5479 - recall: 0.9072 - f1_score_2: 0.6855 - val_loss: 0.6949 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 42/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6901 - binary_accuracy: 0.5350 - precision: 0.5446 - recall: 0.9106 - f1_score_2: 0.6672 - val_loss: 0.6982 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 43/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6902 - binary_accuracy: 0.5435 - precision: 0.5482 - recall: 0.9363 - f1_score_2: 0.6770 - val_loss: 0.6975 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 44/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6901 - binary_accuracy: 0.5339 - precision: 0.5440 - recall: 0.9092 - f1_score_2: 0.6821 - val_loss: 0.7101 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 45/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6915 - binary_accuracy: 0.5313 - precision: 0.5428 - recall: 0.9024 - f1_score_2: 0.6803 - val_loss: 0.6878 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 46/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6912 - binary_accuracy: 0.5354 - precision: 0.5450 - recall: 0.9072 - f1_score_2: 0.6831 - val_loss: 0.6874 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 47/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6896 - binary_accuracy: 0.5520 - precision: 0.5528 - recall: 0.9438 - f1_score_2: 0.6820 - val_loss: 0.6935 - val_binary_accuracy: 0.4817 - val_precision: 0.5556 - val_recall: 0.3846 - val_f1_score_2: 0.3368
# Epoch 48/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6896 - binary_accuracy: 0.5446 - precision: 0.5487 - recall: 0.9383 - f1_score_2: 0.6769 - val_loss: 0.6966 - val_binary_accuracy: 0.4186 - val_precision: 0.4773 - val_recall: 0.3728 - val_f1_score_2: 0.2898
# Epoch 49/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6887 - binary_accuracy: 0.5442 - precision: 0.5519 - recall: 0.8821 - f1_score_2: 0.6815 - val_loss: 0.7022 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 50/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6885 - binary_accuracy: 0.5391 - precision: 0.5473 - recall: 0.9058 - f1_score_2: 0.6677 - val_loss: 0.7135 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 51/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6903 - binary_accuracy: 0.5387 - precision: 0.5484 - recall: 0.8835 - f1_score_2: 0.6797 - val_loss: 0.6990 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 52/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6878 - binary_accuracy: 0.5476 - precision: 0.5515 - recall: 0.9207 - f1_score_2: 0.6935 - val_loss: 0.6932 - val_binary_accuracy: 0.5150 - val_precision: 0.5935 - val_recall: 0.4320 - val_f1_score_2: 0.3095
# Epoch 53/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6893 - binary_accuracy: 0.5417 - precision: 0.5485 - recall: 0.9126 - f1_score_2: 0.6707 - val_loss: 0.6962 - val_binary_accuracy: 0.4518 - val_precision: 0.7000 - val_recall: 0.0414 - val_f1_score_2: 0.0513
# Epoch 54/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6901 - binary_accuracy: 0.5439 - precision: 0.5496 - recall: 0.9167 - f1_score_2: 0.6724 - val_loss: 0.6991 - val_binary_accuracy: 0.4585 - val_precision: 0.6667 - val_recall: 0.0710 - val_f1_score_2: 0.0851
# Epoch 55/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6897 - binary_accuracy: 0.5376 - precision: 0.5464 - recall: 0.9051 - f1_score_2: 0.6849 - val_loss: 0.6889 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 56/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6905 - binary_accuracy: 0.5372 - precision: 0.5465 - recall: 0.9004 - f1_score_2: 0.6830 - val_loss: 0.6940 - val_binary_accuracy: 0.4950 - val_precision: 0.6076 - val_recall: 0.2840 - val_f1_score_2: 0.1924
# Epoch 57/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.6899 - binary_accuracy: 0.5391 - precision: 0.5461 - recall: 0.9268 - f1_score_2: 0.6890 - val_loss: 0.6997 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 58/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6881 - binary_accuracy: 0.5405 - precision: 0.5471 - recall: 0.9255 - f1_score_2: 0.6725 - val_loss: 0.7030 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 59/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6927 - binary_accuracy: 0.5398 - precision: 0.5480 - recall: 0.9004 - f1_score_2: 0.6663 - val_loss: 0.7015 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 60/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.6883 - binary_accuracy: 0.5417 - precision: 0.5478 - recall: 0.9248 - f1_score_2: 0.6914 - val_loss: 0.6979 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 61/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6897 - binary_accuracy: 0.5417 - precision: 0.5494 - recall: 0.8970 - f1_score_2: 0.6664 - val_loss: 0.7032 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 62/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6896 - binary_accuracy: 0.5372 - precision: 0.5463 - recall: 0.9031 - f1_score_2: 0.6840 - val_loss: 0.7032 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 63/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6905 - binary_accuracy: 0.5446 - precision: 0.5489 - recall: 0.9350 - f1_score_2: 0.6748 - val_loss: 0.6994 - val_binary_accuracy: 0.4684 - val_precision: 0.6216 - val_recall: 0.1361 - val_f1_score_2: 0.1331
# Epoch 64/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6897 - binary_accuracy: 0.5420 - precision: 0.5506 - recall: 0.8808 - f1_score_2: 0.6800 - val_loss: 0.6900 - val_binary_accuracy: 0.5714 - val_precision: 0.6389 - val_recall: 0.5444 - val_f1_score_2: 0.3284
# Epoch 65/1000
# 55/55 [==============================] - 1s 10ms/step - loss: 0.6888 - binary_accuracy: 0.5405 - precision: 0.5467 - recall: 0.9316 - f1_score_2: 0.6923 - val_loss: 0.6973 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 66/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.6888 - binary_accuracy: 0.5502 - precision: 0.5529 - recall: 0.9248 - f1_score_2: 0.6759 - val_loss: 0.6937 - val_binary_accuracy: 0.5017 - val_precision: 0.6118 - val_recall: 0.3077 - val_f1_score_2: 0.2015
# Epoch 67/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6880 - binary_accuracy: 0.5472 - precision: 0.5519 - recall: 0.9112 - f1_score_2: 0.6727 - val_loss: 0.6904 - val_binary_accuracy: 0.5382 - val_precision: 0.6210 - val_recall: 0.4556 - val_f1_score_2: 0.2924
# Epoch 68/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6906 - binary_accuracy: 0.5431 - precision: 0.5495 - recall: 0.9092 - f1_score_2: 0.6876 - val_loss: 0.6982 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 69/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.6897 - binary_accuracy: 0.5446 - precision: 0.5529 - recall: 0.8706 - f1_score_2: 0.6776 - val_loss: 0.6903 - val_binary_accuracy: 0.5216 - val_precision: 0.6190 - val_recall: 0.3846 - val_f1_score_2: 0.2405
# Epoch 70/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6884 - binary_accuracy: 0.5472 - precision: 0.5501 - recall: 0.9417 - f1_score_2: 0.6792 - val_loss: 0.6964 - val_binary_accuracy: 0.4884 - val_precision: 0.6000 - val_recall: 0.2663 - val_f1_score_2: 0.1848
# Epoch 71/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6882 - binary_accuracy: 0.5509 - precision: 0.5548 - recall: 0.9018 - f1_score_2: 0.6882 - val_loss: 0.7006 - val_binary_accuracy: 0.4452 - val_precision: 0.7500 - val_recall: 0.0178 - val_f1_score_2: 0.0260
# Epoch 72/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6892 - binary_accuracy: 0.5465 - precision: 0.5512 - recall: 0.9153 - f1_score_2: 0.6907 - val_loss: 0.7012 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 73/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6890 - binary_accuracy: 0.5457 - precision: 0.5508 - recall: 0.9153 - f1_score_2: 0.6726 - val_loss: 0.7103 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 74/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.6902 - binary_accuracy: 0.5383 - precision: 0.5459 - recall: 0.9234 - f1_score_2: 0.6879 - val_loss: 0.7085 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 75/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6909 - binary_accuracy: 0.5354 - precision: 0.5446 - recall: 0.9140 - f1_score_2: 0.6859 - val_loss: 0.6882 - val_binary_accuracy: 0.5648 - val_precision: 0.5742 - val_recall: 0.8698 - val_f1_score_2: 0.7138
# Epoch 76/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6890 - binary_accuracy: 0.5457 - precision: 0.5498 - recall: 0.9316 - f1_score_2: 0.6763 - val_loss: 0.7003 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 77/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6925 - binary_accuracy: 0.5387 - precision: 0.5484 - recall: 0.8828 - f1_score_2: 0.6599 - val_loss: 0.6915 - val_binary_accuracy: 0.5914 - val_precision: 0.6353 - val_recall: 0.6391 - val_f1_score_2: 0.4455
# Epoch 78/1000
# 55/55 [==============================] - 0s 9ms/step - loss: 0.6894 - binary_accuracy: 0.5435 - precision: 0.5489 - recall: 0.9248 - f1_score_2: 0.6915 - val_loss: 0.6943 - val_binary_accuracy: 0.4385 - val_precision: 0.5000 - val_recall: 0.0118 - val_f1_score_2: 0.0150
# Epoch 79/1000
# 55/55 [==============================] - 1s 10ms/step - loss: 0.6883 - binary_accuracy: 0.5450 - precision: 0.5517 - recall: 0.8936 - f1_score_2: 0.6665 - val_loss: 0.6924 - val_binary_accuracy: 0.5282 - val_precision: 0.6262 - val_recall: 0.3964 - val_f1_score_2: 0.2533
# Epoch 80/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6907 - binary_accuracy: 0.5450 - precision: 0.5498 - recall: 0.9241 - f1_score_2: 0.6924 - val_loss: 0.7018 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 81/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6898 - binary_accuracy: 0.5365 - precision: 0.5467 - recall: 0.8882 - f1_score_2: 0.6618 - val_loss: 0.6888 - val_binary_accuracy: 0.5648 - val_precision: 0.5633 - val_recall: 1.0000 - val_f1_score_2: 0.7554
# Epoch 82/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6886 - binary_accuracy: 0.5439 - precision: 0.5482 - recall: 0.9397 - f1_score_2: 0.6763 - val_loss: 0.7179 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 83/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6889 - binary_accuracy: 0.5420 - precision: 0.5497 - recall: 0.8957 - f1_score_2: 0.6663 - val_loss: 0.6990 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 84/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6887 - binary_accuracy: 0.5417 - precision: 0.5500 - recall: 0.8875 - f1_score_2: 0.6816 - val_loss: 0.6884 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 85/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6909 - binary_accuracy: 0.5376 - precision: 0.5449 - recall: 0.9336 - f1_score_2: 0.6903 - val_loss: 0.6947 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 86/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6900 - binary_accuracy: 0.5428 - precision: 0.5494 - recall: 0.9072 - f1_score_2: 0.6875 - val_loss: 0.6990 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 87/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6894 - binary_accuracy: 0.5428 - precision: 0.5475 - recall: 0.9411 - f1_score_2: 0.6764 - val_loss: 0.6980 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 88/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6895 - binary_accuracy: 0.5365 - precision: 0.5464 - recall: 0.8943 - f1_score_2: 0.6628 - val_loss: 0.6883 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 89/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6895 - binary_accuracy: 0.5328 - precision: 0.5449 - recall: 0.8794 - f1_score_2: 0.6750 - val_loss: 0.6900 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 90/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6875 - binary_accuracy: 0.5435 - precision: 0.5505 - recall: 0.8977 - f1_score_2: 0.6851 - val_loss: 0.7060 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 91/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6889 - binary_accuracy: 0.5439 - precision: 0.5525 - recall: 0.8699 - f1_score_2: 0.6770 - val_loss: 0.6869 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 92/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6908 - binary_accuracy: 0.5402 - precision: 0.5457 - recall: 0.9465 - f1_score_2: 0.6943 - val_loss: 0.6953 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 93/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6892 - binary_accuracy: 0.5435 - precision: 0.5488 - recall: 0.9262 - f1_score_2: 0.6727 - val_loss: 0.6990 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 94/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6900 - binary_accuracy: 0.5398 - precision: 0.5456 - recall: 0.9451 - f1_score_2: 0.6939 - val_loss: 0.6913 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 95/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6906 - binary_accuracy: 0.5368 - precision: 0.5447 - recall: 0.9282 - f1_score_2: 0.6893 - val_loss: 0.6956 - val_binary_accuracy: 0.4252 - val_precision: 0.4091 - val_recall: 0.0533 - val_f1_score_2: 0.0756
# Epoch 96/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6878 - binary_accuracy: 0.5450 - precision: 0.5496 - recall: 0.9268 - f1_score_2: 0.6751 - val_loss: 0.6866 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 97/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6887 - binary_accuracy: 0.5450 - precision: 0.5503 - recall: 0.9146 - f1_score_2: 0.6903 - val_loss: 0.6869 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 98/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6903 - binary_accuracy: 0.5428 - precision: 0.5473 - recall: 0.9451 - f1_score_2: 0.6944 - val_loss: 0.6948 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 99/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6884 - binary_accuracy: 0.5550 - precision: 0.5546 - recall: 0.9431 - f1_score_2: 0.7004 - val_loss: 0.6904 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 100/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6886 - binary_accuracy: 0.5413 - precision: 0.5474 - recall: 0.9268 - f1_score_2: 0.6907 - val_loss: 0.6988 - val_binary_accuracy: 0.4219 - val_precision: 0.4783 - val_recall: 0.3254 - val_f1_score_2: 0.2455
# Epoch 101/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6899 - binary_accuracy: 0.5442 - precision: 0.5508 - recall: 0.9004 - f1_score_2: 0.6688 - val_loss: 0.6944 - val_binary_accuracy: 0.4950 - val_precision: 0.5350 - val_recall: 0.7692 - val_f1_score_2: 0.6687
# Epoch 102/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6895 - binary_accuracy: 0.5435 - precision: 0.5487 - recall: 0.9275 - f1_score_2: 0.6918 - val_loss: 0.6989 - val_binary_accuracy: 0.4352 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 103/1000
# 55/55 [==============================] - 1s 9ms/step - loss: 0.6897 - binary_accuracy: 0.5439 - precision: 0.5487 - recall: 0.9316 - f1_score_2: 0.6929 - val_loss: 0.6927 - val_binary_accuracy: 0.5216 - val_precision: 0.6238 - val_recall: 0.3728 - val_f1_score_2: 0.2514
# Epoch 104/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6908 - binary_accuracy: 0.5398 - precision: 0.5484 - recall: 0.8950 - f1_score_2: 0.6822 - val_loss: 0.6864 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 105/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6899 - binary_accuracy: 0.5465 - precision: 0.5484 - recall: 0.9627 - f1_score_2: 0.7020 - val_loss: 0.6958 - val_binary_accuracy: 0.4385 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_f1_score_2: 0.0000e+00
# Epoch 106/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6896 - binary_accuracy: 0.5350 - precision: 0.5430 - recall: 0.9404 - f1_score_2: 0.6915 - val_loss: 0.6906 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541
# Epoch 107/1000
# 55/55 [==============================] - 0s 8ms/step - loss: 0.6892 - binary_accuracy: 0.5465 - precision: 0.5487 - recall: 0.9573 - f1_score_2: 0.6825 - val_loss: 0.6903 - val_binary_accuracy: 0.5615 - val_precision: 0.5615 - val_recall: 1.0000 - val_f1_score_2: 0.7541

# %%
# predict with testing dataset
y_pred_prob = model.predict(X_test_reshaped)

# convert probabilities to binary class labels
y_pred = (y_pred_prob >= 0.5).astype(int)

# evaluate the prediction performance
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1-score:", f1_score(y_test, y_pred))
# Out:
# 24/24 [==============================] - 1s 2ms/step
# Accuracy: 0.49866310160427807
# Precision: 0.49866310160427807
# Recall: 1.0
# F1-score: 0.6654772524531669

# %%
time = df['timestamp']
time_train, time_test = train_test_split(time, test_size=0.2, shuffle=False)
time_test = time_test[timesteps-1:]

# Flatten y_pred to be a 1-dimensional array
y_pred_flat = y_pred.flatten()

# Create a DataFrame with columns time_test, y_test, and y_pred
pred_res = pd.DataFrame({'date': time_test, 'actual': y_test.values, 'prediction': y_pred_flat, 'value': price['today'][-748:]})

pred_res.to_csv('pred/lstm-cnn_uni_data.csv', index=False)
