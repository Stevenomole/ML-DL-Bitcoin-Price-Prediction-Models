# %%
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, matthews_corrcoef
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import metrics
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tcn import TCN
import os
import random
import tensorflow as tf

# %%
# resetting the seeds for reproducibility
def reset_random_seeds():
    n = 1
    os.environ['PYTHONHASHSEED'] = str(n)
    tf.random.set_seed(n)
    np.random.seed(n)
    random.seed(n)

reset_random_seeds()

# import data
df = pd.read_csv('Boruta_onchain_data.csv')
df1 = pd.read_csv('all_data.csv')

df = df[df['timestamp'] >= '2013-03-11'].reset_index(drop=True)

#onchain_data_new
#TA_data
#all_data
#Boruta_data
#Boruta_TA_data
#Boruta_onchain_data

# %%
# separate the inputs and target
X = df.drop('timestamp', axis=1)

# create binary classification for price movement. this assigns 1 to y if price will move upward next day.
price = pd.DataFrame()
price['today'] = df1['price-ohlc-usd-c']
price['next day'] = price['today'].shift(-1)
y = price['next day']

# Drop the last row where 'next day' would be NaN after shifting
X = X[:-1]
y = y.dropna()

# separate training data from testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# scale the input data
scaler = StandardScaler()

# Reshape X_train and X_test if they are 1D
if X_train.ndim == 1:
    X_train = X_train.to_numpy().reshape(-1, 1)
if X_test.ndim == 1:
    X_test = X_test.to_numpy().reshape(-1, 1)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# reshape the input data for CNN-LSTM (samples, timesteps, features)
def create_sequences(data, timesteps):
    X = []
    for i in range(len(data) - timesteps + 1):
        X.append(data[i:i + timesteps])
    return np.array(X)

timesteps = 5
X_train_reshaped = create_sequences(X_train_scaled, timesteps)
X_test_reshaped = create_sequences(X_test_scaled, timesteps)
y_train = y_train[timesteps - 1:]
y_test = y_test[timesteps - 1:]

# %%
# define the TCN model
model = Sequential()

# First TCN layer
model.add(TCN(input_shape=(timesteps, X_train_reshaped.shape[2]), 
              nb_filters=64, 
              kernel_size=3, 
              dilations=[1, 2, 4, 8], 
              activation='relu',
              return_sequences=True))  # Ensures 3D output for the next TCN layer
model.add(Dropout(0.5))

# Second TCN layer
model.add(TCN(nb_filters=64, 
              kernel_size=3, 
              dilations=[1, 2, 4, 8, 16], 
              activation='relu',
              return_sequences=False))  # Returns 2D output for Dense layer
model.add(Dropout(0.5))

# Dense output layer
model.add(Dense(1, activation='relu'))

# compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_absolute_error', metrics=['mean_absolute_error', 'mean_squared_error'])
# Out:
# C:\Users\oluwa\AppData\Roaming\Python\Python312\site-packages\tcn\tcn.py:227: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super(TCN, self).__init__(**kwargs)
# WARNING:tensorflow:From C:\Users\oluwa\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\core.py:216: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
model.save("tcn_r_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# train with the training dataset
early_stopping = EarlyStopping(monitor='val_loss', patience=50)
history = model.fit(X_train_reshaped, y_train, epochs=100, batch_size=50, validation_split=0.1, callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 3012.1135 - mean_absolute_error: 3012.1135 - mean_squared_error: 20978066.0000 - val_loss: 6591.0708 - val_mean_absolute_error: 6591.0708 - val_mean_squared_error: 84246096.0000
# Epoch 2/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1004.7516 - mean_absolute_error: 1004.7516 - mean_squared_error: 3028024.5000 - val_loss: 4165.7529 - val_mean_absolute_error: 4165.7529 - val_mean_squared_error: 36618900.0000
# Epoch 3/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 769.3553 - mean_absolute_error: 769.3553 - mean_squared_error: 1837991.0000 - val_loss: 3122.6692 - val_mean_absolute_error: 3122.6692 - val_mean_squared_error: 21400754.0000
# Epoch 4/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 668.0773 - mean_absolute_error: 668.0773 - mean_squared_error: 1416267.3750 - val_loss: 2677.7512 - val_mean_absolute_error: 2677.7512 - val_mean_squared_error: 16054566.0000
# Epoch 5/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 666.6434 - mean_absolute_error: 666.6433 - mean_squared_error: 1332254.8750 - val_loss: 5840.0498 - val_mean_absolute_error: 5840.0498 - val_mean_squared_error: 55036188.0000
# Epoch 6/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 731.6589 - mean_absolute_error: 731.6589 - mean_squared_error: 1685777.7500 - val_loss: 2861.1333 - val_mean_absolute_error: 2861.1333 - val_mean_squared_error: 17849948.0000
# Epoch 7/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 689.0607 - mean_absolute_error: 689.0607 - mean_squared_error: 1580521.5000 - val_loss: 2741.0508 - val_mean_absolute_error: 2741.0508 - val_mean_squared_error: 16264704.0000
# Epoch 8/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 633.5922 - mean_absolute_error: 633.5922 - mean_squared_error: 1346736.8750 - val_loss: 3214.5881 - val_mean_absolute_error: 3214.5881 - val_mean_squared_error: 21838310.0000
# Epoch 9/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 637.9818 - mean_absolute_error: 637.9818 - mean_squared_error: 1379916.8750 - val_loss: 5043.5107 - val_mean_absolute_error: 5043.5107 - val_mean_squared_error: 45077164.0000
# Epoch 10/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 637.9408 - mean_absolute_error: 637.9408 - mean_squared_error: 1301237.2500 - val_loss: 2538.2429 - val_mean_absolute_error: 2538.2429 - val_mean_squared_error: 13406224.0000
# Epoch 11/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 617.3290 - mean_absolute_error: 617.3290 - mean_squared_error: 1270719.2500 - val_loss: 2383.5344 - val_mean_absolute_error: 2383.5344 - val_mean_squared_error: 12608600.0000
# Epoch 12/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 607.1174 - mean_absolute_error: 607.1174 - mean_squared_error: 1185536.5000 - val_loss: 2984.8279 - val_mean_absolute_error: 2984.8279 - val_mean_squared_error: 17478024.0000
# Epoch 13/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 634.7352 - mean_absolute_error: 634.7352 - mean_squared_error: 1345283.5000 - val_loss: 2390.0127 - val_mean_absolute_error: 2390.0127 - val_mean_squared_error: 12006091.0000
# Epoch 14/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 592.6671 - mean_absolute_error: 592.6671 - mean_squared_error: 1341403.8750 - val_loss: 2305.5227 - val_mean_absolute_error: 2305.5227 - val_mean_squared_error: 14365747.0000
# Epoch 15/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 663.6221 - mean_absolute_error: 663.6221 - mean_squared_error: 1593501.6250 - val_loss: 6330.1436 - val_mean_absolute_error: 6330.1436 - val_mean_squared_error: 62591104.0000
# Epoch 16/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 613.5211 - mean_absolute_error: 613.5211 - mean_squared_error: 1231394.2500 - val_loss: 6283.1602 - val_mean_absolute_error: 6283.1602 - val_mean_squared_error: 61155628.0000
# Epoch 17/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 617.7326 - mean_absolute_error: 617.7326 - mean_squared_error: 1309674.6250 - val_loss: 4250.4316 - val_mean_absolute_error: 4250.4312 - val_mean_squared_error: 31650152.0000
# Epoch 18/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 649.2437 - mean_absolute_error: 649.2437 - mean_squared_error: 1330980.5000 - val_loss: 2874.2026 - val_mean_absolute_error: 2874.2024 - val_mean_squared_error: 16264134.0000
# Epoch 19/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 549.4396 - mean_absolute_error: 549.4396 - mean_squared_error: 1007492.5625 - val_loss: 3431.3179 - val_mean_absolute_error: 3431.3179 - val_mean_squared_error: 23284480.0000
# Epoch 20/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 585.7842 - mean_absolute_error: 585.7842 - mean_squared_error: 1175385.5000 - val_loss: 4511.0225 - val_mean_absolute_error: 4511.0225 - val_mean_squared_error: 36715668.0000
# Epoch 21/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 557.7972 - mean_absolute_error: 557.7972 - mean_squared_error: 1070241.2500 - val_loss: 3221.0842 - val_mean_absolute_error: 3221.0842 - val_mean_squared_error: 20551592.0000
# Epoch 22/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 571.5146 - mean_absolute_error: 571.5146 - mean_squared_error: 1170426.2500 - val_loss: 4297.4800 - val_mean_absolute_error: 4297.4800 - val_mean_squared_error: 31119098.0000
# Epoch 23/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 540.6396 - mean_absolute_error: 540.6396 - mean_squared_error: 1025341.6875 - val_loss: 2243.0693 - val_mean_absolute_error: 2243.0693 - val_mean_squared_error: 9889470.0000
# Epoch 24/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 574.3060 - mean_absolute_error: 574.3060 - mean_squared_error: 1121483.1250 - val_loss: 3558.0825 - val_mean_absolute_error: 3558.0825 - val_mean_squared_error: 22314182.0000
# Epoch 25/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 567.7554 - mean_absolute_error: 567.7554 - mean_squared_error: 1078579.5000 - val_loss: 5769.1772 - val_mean_absolute_error: 5769.1772 - val_mean_squared_error: 51312968.0000
# Epoch 26/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 570.5636 - mean_absolute_error: 570.5636 - mean_squared_error: 1082575.6250 - val_loss: 3005.4929 - val_mean_absolute_error: 3005.4929 - val_mean_squared_error: 16043236.0000
# Epoch 27/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 575.0300 - mean_absolute_error: 575.0300 - mean_squared_error: 1093358.7500 - val_loss: 5346.0469 - val_mean_absolute_error: 5346.0469 - val_mean_squared_error: 44297512.0000
# Epoch 28/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 568.7081 - mean_absolute_error: 568.7081 - mean_squared_error: 1100170.2500 - val_loss: 2768.0515 - val_mean_absolute_error: 2768.0515 - val_mean_squared_error: 14056768.0000
# Epoch 29/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 544.7150 - mean_absolute_error: 544.7150 - mean_squared_error: 1063344.8750 - val_loss: 2760.1509 - val_mean_absolute_error: 2760.1509 - val_mean_squared_error: 14823790.0000
# Epoch 30/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 530.3574 - mean_absolute_error: 530.3574 - mean_squared_error: 1011026.3125 - val_loss: 2877.4719 - val_mean_absolute_error: 2877.4717 - val_mean_squared_error: 15091576.0000
# Epoch 31/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 558.6497 - mean_absolute_error: 558.6497 - mean_squared_error: 1054779.3750 - val_loss: 2000.5972 - val_mean_absolute_error: 2000.5972 - val_mean_squared_error: 8601272.0000
# Epoch 32/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 553.1531 - mean_absolute_error: 553.1531 - mean_squared_error: 1039192.9375 - val_loss: 3028.4148 - val_mean_absolute_error: 3028.4148 - val_mean_squared_error: 15512098.0000
# Epoch 33/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 531.6263 - mean_absolute_error: 531.6262 - mean_squared_error: 1089986.0000 - val_loss: 2581.1526 - val_mean_absolute_error: 2581.1526 - val_mean_squared_error: 12605358.0000
# Epoch 34/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 528.0791 - mean_absolute_error: 528.0790 - mean_squared_error: 906327.3750 - val_loss: 4338.4727 - val_mean_absolute_error: 4338.4727 - val_mean_squared_error: 32817760.0000
# Epoch 35/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 501.0805 - mean_absolute_error: 501.0805 - mean_squared_error: 856938.1250 - val_loss: 1981.7163 - val_mean_absolute_error: 1981.7163 - val_mean_squared_error: 9739213.0000
# Epoch 36/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 540.3599 - mean_absolute_error: 540.3599 - mean_squared_error: 1005433.4375 - val_loss: 1834.8295 - val_mean_absolute_error: 1834.8295 - val_mean_squared_error: 8525241.0000
# Epoch 37/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 518.0510 - mean_absolute_error: 518.0510 - mean_squared_error: 971523.2500 - val_loss: 2182.9563 - val_mean_absolute_error: 2182.9563 - val_mean_squared_error: 8886146.0000
# Epoch 38/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 531.2954 - mean_absolute_error: 531.2953 - mean_squared_error: 957906.0000 - val_loss: 4970.5718 - val_mean_absolute_error: 4970.5718 - val_mean_squared_error: 38969492.0000
# Epoch 39/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 540.9409 - mean_absolute_error: 540.9409 - mean_squared_error: 973293.7500 - val_loss: 6994.1694 - val_mean_absolute_error: 6994.1694 - val_mean_squared_error: 71793440.0000
# Epoch 40/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 531.0400 - mean_absolute_error: 531.0400 - mean_squared_error: 919753.0000 - val_loss: 3832.4497 - val_mean_absolute_error: 3832.4497 - val_mean_squared_error: 24648920.0000
# Epoch 41/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 525.2089 - mean_absolute_error: 525.2089 - mean_squared_error: 933121.1250 - val_loss: 3089.5417 - val_mean_absolute_error: 3089.5417 - val_mean_squared_error: 17616164.0000
# Epoch 42/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 506.2031 - mean_absolute_error: 506.2031 - mean_squared_error: 895512.5625 - val_loss: 2938.7695 - val_mean_absolute_error: 2938.7695 - val_mean_squared_error: 14574514.0000
# Epoch 43/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 495.6246 - mean_absolute_error: 495.6246 - mean_squared_error: 882775.1875 - val_loss: 3372.9888 - val_mean_absolute_error: 3372.9888 - val_mean_squared_error: 19828468.0000
# Epoch 44/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 488.9913 - mean_absolute_error: 488.9913 - mean_squared_error: 804323.7500 - val_loss: 1671.7312 - val_mean_absolute_error: 1671.7312 - val_mean_squared_error: 7227240.5000
# Epoch 45/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 529.6987 - mean_absolute_error: 529.6987 - mean_squared_error: 922800.3125 - val_loss: 1663.6818 - val_mean_absolute_error: 1663.6818 - val_mean_squared_error: 6867090.0000
# Epoch 46/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 507.6823 - mean_absolute_error: 507.6823 - mean_squared_error: 858686.3125 - val_loss: 4201.3901 - val_mean_absolute_error: 4201.3901 - val_mean_squared_error: 28922880.0000
# Epoch 47/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 470.9998 - mean_absolute_error: 470.9998 - mean_squared_error: 753723.5625 - val_loss: 3467.5776 - val_mean_absolute_error: 3467.5776 - val_mean_squared_error: 20857528.0000
# Epoch 48/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 469.6195 - mean_absolute_error: 469.6195 - mean_squared_error: 752029.3750 - val_loss: 2510.5891 - val_mean_absolute_error: 2510.5891 - val_mean_squared_error: 11100276.0000
# Epoch 49/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 475.6093 - mean_absolute_error: 475.6093 - mean_squared_error: 736741.1875 - val_loss: 2474.9324 - val_mean_absolute_error: 2474.9324 - val_mean_squared_error: 11428821.0000
# Epoch 50/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 483.2693 - mean_absolute_error: 483.2693 - mean_squared_error: 824309.6250 - val_loss: 5413.3672 - val_mean_absolute_error: 5413.3662 - val_mean_squared_error: 45145940.0000
# Epoch 51/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 491.7190 - mean_absolute_error: 491.7190 - mean_squared_error: 794783.5625 - val_loss: 1658.8531 - val_mean_absolute_error: 1658.8531 - val_mean_squared_error: 5807692.5000
# Epoch 52/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 524.6434 - mean_absolute_error: 524.6434 - mean_squared_error: 957568.8125 - val_loss: 2858.5818 - val_mean_absolute_error: 2858.5818 - val_mean_squared_error: 13588341.0000
# Epoch 53/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 486.4242 - mean_absolute_error: 486.4242 - mean_squared_error: 784859.5000 - val_loss: 3654.4978 - val_mean_absolute_error: 3654.4976 - val_mean_squared_error: 21685220.0000
# Epoch 54/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 454.6218 - mean_absolute_error: 454.6218 - mean_squared_error: 665641.1250 - val_loss: 3375.7322 - val_mean_absolute_error: 3375.7322 - val_mean_squared_error: 18115374.0000
# Epoch 55/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 455.5044 - mean_absolute_error: 455.5044 - mean_squared_error: 740547.7500 - val_loss: 4124.9189 - val_mean_absolute_error: 4124.9189 - val_mean_squared_error: 26387514.0000
# Epoch 56/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 535.7936 - mean_absolute_error: 535.7936 - mean_squared_error: 1009867.4375 - val_loss: 3037.6951 - val_mean_absolute_error: 3037.6951 - val_mean_squared_error: 15129682.0000
# Epoch 57/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 486.7031 - mean_absolute_error: 486.7031 - mean_squared_error: 822099.9375 - val_loss: 1865.9207 - val_mean_absolute_error: 1865.9207 - val_mean_squared_error: 7106945.5000
# Epoch 58/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 483.4154 - mean_absolute_error: 483.4154 - mean_squared_error: 798723.0625 - val_loss: 5630.6431 - val_mean_absolute_error: 5630.6431 - val_mean_squared_error: 47226372.0000
# Epoch 59/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 472.6092 - mean_absolute_error: 472.6092 - mean_squared_error: 749788.0000 - val_loss: 5451.1729 - val_mean_absolute_error: 5451.1729 - val_mean_squared_error: 45480780.0000
# Epoch 60/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 461.2796 - mean_absolute_error: 461.2796 - mean_squared_error: 743017.9375 - val_loss: 2702.2144 - val_mean_absolute_error: 2702.2144 - val_mean_squared_error: 12583661.0000
# Epoch 61/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 480.6602 - mean_absolute_error: 480.6602 - mean_squared_error: 807487.0000 - val_loss: 5735.6367 - val_mean_absolute_error: 5735.6367 - val_mean_squared_error: 48253480.0000
# Epoch 62/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 537.8892 - mean_absolute_error: 537.8892 - mean_squared_error: 1009379.3750 - val_loss: 4665.4541 - val_mean_absolute_error: 4665.4541 - val_mean_squared_error: 34157168.0000
# Epoch 63/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 466.1649 - mean_absolute_error: 466.1649 - mean_squared_error: 728869.1250 - val_loss: 3692.5913 - val_mean_absolute_error: 3692.5913 - val_mean_squared_error: 22265838.0000
# Epoch 64/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 472.4947 - mean_absolute_error: 472.4947 - mean_squared_error: 808242.3125 - val_loss: 1842.9280 - val_mean_absolute_error: 1842.9280 - val_mean_squared_error: 6923628.0000
# Epoch 65/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 506.5178 - mean_absolute_error: 506.5178 - mean_squared_error: 895009.3125 - val_loss: 7700.9019 - val_mean_absolute_error: 7700.9019 - val_mean_squared_error: 85925072.0000
# Epoch 66/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 508.8333 - mean_absolute_error: 508.8333 - mean_squared_error: 841310.8125 - val_loss: 6790.2446 - val_mean_absolute_error: 6790.2446 - val_mean_squared_error: 68724016.0000
# Epoch 67/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 448.0276 - mean_absolute_error: 448.0276 - mean_squared_error: 684981.8750 - val_loss: 5713.4971 - val_mean_absolute_error: 5713.4971 - val_mean_squared_error: 48453484.0000
# Epoch 68/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 456.4968 - mean_absolute_error: 456.4968 - mean_squared_error: 705918.7500 - val_loss: 5315.6206 - val_mean_absolute_error: 5315.6206 - val_mean_squared_error: 43644172.0000
# Epoch 69/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 497.7176 - mean_absolute_error: 497.7176 - mean_squared_error: 850988.2500 - val_loss: 2589.6692 - val_mean_absolute_error: 2589.6692 - val_mean_squared_error: 11937975.0000
# Epoch 70/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 446.4323 - mean_absolute_error: 446.4322 - mean_squared_error: 721545.1875 - val_loss: 5529.4331 - val_mean_absolute_error: 5529.4331 - val_mean_squared_error: 45625708.0000
# Epoch 71/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 560.0830 - mean_absolute_error: 560.0830 - mean_squared_error: 1051159.2500 - val_loss: 5229.8462 - val_mean_absolute_error: 5229.8462 - val_mean_squared_error: 40393508.0000
# Epoch 72/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 513.1873 - mean_absolute_error: 513.1873 - mean_squared_error: 858247.4375 - val_loss: 5498.9707 - val_mean_absolute_error: 5498.9707 - val_mean_squared_error: 46004512.0000
# Epoch 73/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 453.6348 - mean_absolute_error: 453.6348 - mean_squared_error: 701368.0625 - val_loss: 2724.9900 - val_mean_absolute_error: 2724.9900 - val_mean_squared_error: 13657732.0000
# Epoch 74/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 448.4355 - mean_absolute_error: 448.4355 - mean_squared_error: 716333.0000 - val_loss: 5337.8901 - val_mean_absolute_error: 5337.8901 - val_mean_squared_error: 42965996.0000
# Epoch 75/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 436.3518 - mean_absolute_error: 436.3518 - mean_squared_error: 620057.7500 - val_loss: 4450.6890 - val_mean_absolute_error: 4450.6890 - val_mean_squared_error: 31809260.0000
# Epoch 76/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 433.9346 - mean_absolute_error: 433.9346 - mean_squared_error: 663020.3125 - val_loss: 3729.0466 - val_mean_absolute_error: 3729.0466 - val_mean_squared_error: 23365660.0000
# Epoch 77/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 465.3468 - mean_absolute_error: 465.3468 - mean_squared_error: 722990.6875 - val_loss: 5831.3335 - val_mean_absolute_error: 5831.3335 - val_mean_squared_error: 48853716.0000
# Epoch 78/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 448.9105 - mean_absolute_error: 448.9105 - mean_squared_error: 700797.5625 - val_loss: 7288.8022 - val_mean_absolute_error: 7288.8022 - val_mean_squared_error: 73725856.0000
# Epoch 79/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 523.9282 - mean_absolute_error: 523.9282 - mean_squared_error: 912534.8750 - val_loss: 4168.7710 - val_mean_absolute_error: 4168.7710 - val_mean_squared_error: 27352498.0000
# Epoch 80/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 421.1895 - mean_absolute_error: 421.1895 - mean_squared_error: 600077.5000 - val_loss: 6903.9873 - val_mean_absolute_error: 6903.9873 - val_mean_squared_error: 67486144.0000
# Epoch 81/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 467.0754 - mean_absolute_error: 467.0754 - mean_squared_error: 794750.5000 - val_loss: 7210.4395 - val_mean_absolute_error: 7210.4395 - val_mean_squared_error: 73090520.0000
# Epoch 82/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 459.4900 - mean_absolute_error: 459.4900 - mean_squared_error: 727364.1250 - val_loss: 5380.3594 - val_mean_absolute_error: 5380.3594 - val_mean_squared_error: 44108640.0000
# Epoch 83/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 454.2529 - mean_absolute_error: 454.2529 - mean_squared_error: 754121.0000 - val_loss: 6901.9312 - val_mean_absolute_error: 6901.9312 - val_mean_squared_error: 65561976.0000
# Epoch 84/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 496.7976 - mean_absolute_error: 496.7976 - mean_squared_error: 913914.6875 - val_loss: 4078.9714 - val_mean_absolute_error: 4078.9714 - val_mean_squared_error: 25439768.0000
# Epoch 85/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 443.9767 - mean_absolute_error: 443.9767 - mean_squared_error: 665456.1875 - val_loss: 5017.7407 - val_mean_absolute_error: 5017.7407 - val_mean_squared_error: 36839196.0000
# Epoch 86/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 474.1936 - mean_absolute_error: 474.1936 - mean_squared_error: 753804.0000 - val_loss: 3966.8271 - val_mean_absolute_error: 3966.8271 - val_mean_squared_error: 24612026.0000
# Epoch 87/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 467.1960 - mean_absolute_error: 467.1960 - mean_squared_error: 756397.3125 - val_loss: 4803.4263 - val_mean_absolute_error: 4803.4263 - val_mean_squared_error: 34788028.0000
# Epoch 88/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 450.4104 - mean_absolute_error: 450.4104 - mean_squared_error: 741545.6875 - val_loss: 7684.0986 - val_mean_absolute_error: 7684.0986 - val_mean_squared_error: 81003744.0000
# Epoch 89/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 444.4138 - mean_absolute_error: 444.4139 - mean_squared_error: 691384.1875 - val_loss: 4057.6494 - val_mean_absolute_error: 4057.6494 - val_mean_squared_error: 23913662.0000
# Epoch 90/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 440.7287 - mean_absolute_error: 440.7287 - mean_squared_error: 670987.6250 - val_loss: 5797.3926 - val_mean_absolute_error: 5797.3926 - val_mean_squared_error: 47220780.0000
# Epoch 91/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 457.9270 - mean_absolute_error: 457.9270 - mean_squared_error: 684438.2500 - val_loss: 5429.9121 - val_mean_absolute_error: 5429.9121 - val_mean_squared_error: 41991364.0000
# Epoch 92/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 476.1627 - mean_absolute_error: 476.1627 - mean_squared_error: 752316.1250 - val_loss: 7655.0674 - val_mean_absolute_error: 7655.0674 - val_mean_squared_error: 81528448.0000
# Epoch 93/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 454.4189 - mean_absolute_error: 454.4189 - mean_squared_error: 704636.1875 - val_loss: 6470.1982 - val_mean_absolute_error: 6470.1973 - val_mean_squared_error: 58447676.0000
# Epoch 94/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 441.7347 - mean_absolute_error: 441.7347 - mean_squared_error: 681764.2500 - val_loss: 5516.9058 - val_mean_absolute_error: 5516.9058 - val_mean_squared_error: 44096964.0000
# Epoch 95/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 452.3349 - mean_absolute_error: 452.3349 - mean_squared_error: 724178.9375 - val_loss: 3895.3052 - val_mean_absolute_error: 3895.3052 - val_mean_squared_error: 23401076.0000
# Epoch 96/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 443.4866 - mean_absolute_error: 443.4866 - mean_squared_error: 649847.7500 - val_loss: 8352.7256 - val_mean_absolute_error: 8352.7256 - val_mean_squared_error: 97828648.0000
# Epoch 97/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 527.7384 - mean_absolute_error: 527.7384 - mean_squared_error: 987248.7500 - val_loss: 4591.6777 - val_mean_absolute_error: 4591.6777 - val_mean_squared_error: 34257544.0000
# Epoch 98/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 426.5760 - mean_absolute_error: 426.5760 - mean_squared_error: 635805.9375 - val_loss: 6607.0889 - val_mean_absolute_error: 6607.0889 - val_mean_squared_error: 61976432.0000
# Epoch 99/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 438.3751 - mean_absolute_error: 438.3751 - mean_squared_error: 617988.9375 - val_loss: 4658.7739 - val_mean_absolute_error: 4658.7739 - val_mean_squared_error: 32442722.0000
# Epoch 100/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 444.0527 - mean_absolute_error: 444.0527 - mean_squared_error: 682422.0625 - val_loss: 7212.7749 - val_mean_absolute_error: 7212.7749 - val_mean_squared_error: 73116360.0000

# %%
# predict with testing dataset
y_pred = model.predict(X_test_reshaped)

# %%
# evaluate the prediction performance
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("R^2 Score:", r2_score(y_test, y_pred))

# %%
time = df['timestamp']
time_train, time_test = train_test_split(time, test_size=0.2, shuffle=False)
time_test = time_test[timesteps:]

# Flatten y_pred to be a 1-dimensional array
y_pred_flat = y_pred.flatten()

# Create a DataFrame with columns time_test, y_test, and y_pred
pred_res = pd.DataFrame({'date': time_test, 'actual': y_test.values, 'prediction': y_pred_flat, 'value': price['today'][-748:]})

pred_res.to_csv('pred2/tcn_uni_data.csv', index=False)
